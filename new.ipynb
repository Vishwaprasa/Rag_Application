# %%
import sys

print(sys.executable)
# Out:
# c:\D\Working\Projects\Rag_Application\venv\python.exe

# %%
from secret_key import openai_key
import os

os.environ["OPENAI_API_KEY"] = openai_key

# %%
import os
import requests
from secret_key import openai_key

os.environ["OPENAI_API_KEY"] = openai_key

response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers={
        "Authorization": f"Bearer {openai_key}",
        "Content-Type": "application/json",
    },
    json={
        "model": "gpt-4o",
        "messages": [
            {
                "role": "user",
                "content": "I want to open a restaurant for Italian food. Suggest a fancy name.",
            }
        ],
        "temperature": 0.9,
        "max_tokens": 200,
    },
)
# response.raise_for_status()
result = response.json()
print(result)
# Out:
# {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************xcoA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
